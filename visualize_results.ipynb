# %%
import sqlite3
import pandas as pd

# Codes to exclude (vacant/empty properties)
vacant_property_codes = [
    100, 300, 400,    # agricultural, industrial, commercial vacant land/parcels
    500, 501, 502, 503, 504,    # residential vacant lots (platted & unplatted)
    505                   # large‐acre vacant residential & support‐land parcels
]

conn = sqlite3.connect('community_solar.db')
placeholders = ",".join(str(c) for c in vacant_property_codes)

query = f"""
SELECT
    *
FROM 
    LOCATIONS
WHERE 
 dlgf_prop_class_code IN ({placeholders})
"""

df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#         location_id  has_solar_data   latitude  longitude  \
# 0                33               1  40.588744 -84.941469
# 1                40               1  40.665312 -84.950378
# 2                79               1  40.742562 -85.065307
# 3                92               1  40.599733 -84.962114
# 4                93               1  40.832749 -84.931694
# ...             ...             ...        ...        ...
# 139497      3291395               0  39.212721 -86.604022
# 139498      3291396               0  39.212936 -86.604084
# 139499      3291397               0  39.213180 -86.604129
# 139500      3291398               0  39.213383 -86.604256
# 139501      3291399               0  39.211457 -86.602778
#
#         dlgf_prop_class_code            geofulladdress      geocity geostate  \
# 0                        300  10841 S COUNTY ROAD 50 W      DECATUR       IN
# 1                        500             105 W PARR RD        BERNE       IN
# 2                        500       6689 STATE ROAD 124      DECATUR       IN
# 3                        500                 135 SHORE      DECATUR       IN
# 4                        300           806 NUTTMAN AVE      DECATUR       IN
# ...                      ...                       ...          ...      ...
# 139497                   100     4442 N SEABISCUIT CIR  BLOOMINGTON       IN
# 139498                   100     4444 N SEABISCUIT CIR  BLOOMINGTON       IN
# 139499                   100     4446 N SEABISCUIT CIR  BLOOMINGTON       IN
# 139500                   100     4448 N SEABISCUIT CIR  BLOOMINGTON       IN
# 139501                   100       4325 N PREAKNESS LN  BLOOMINGTON       IN
#
#        geozip geocounty         geobg10         geobg20
# 0       46740     ADAMS  180010307002.0  180010307002.0
# 1       46711     ADAMS  180010306002.0  180010306002.0
# 2       46733     ADAMS  180010305004.0  180010305004.0
# 3       46740     ADAMS  180010307003.0  180010307003.0
# 4       46733     ADAMS  180010302002.0  180010302002.0
# ...       ...       ...             ...             ...
# 139497  47404    MONROE  181050013051.0  181050013051.0
# 139498  47404    MONROE  181050013051.0  181050013051.0
# 139499  47404    MONROE  181050013051.0  181050013051.0
# 139500  47404    MONROE  181050013051.0  181050013051.0
# 139501  47404    MONROE  181050013051.0  181050013051.0
#
# [139502 rows x 12 columns]

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('community_solar.db')
query = """
SELECT
    * 
FROM 
    LOCATIONS 
WHERE 
    has_solar_data != 0
"""
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#       location_id  has_solar_data   latitude  longitude dlgf_prop_class_code  \
# 0               1               1  40.917392 -85.045578                  511
# 1               2               1  40.919167 -84.974199                  511
# 2               3               1  40.875888 -84.925602                  101
# 3               4               1  40.853995 -84.925247                  499
# 4               5               1  40.853538 -84.987716                  101
# ...           ...             ...        ...        ...                  ...
# 4025      2470438               1  37.831063 -87.671020                  100
# 4026      2493160               1  37.835373 -87.628316                  100
# 4027      2496080               1  37.834593 -87.633982                  100
# 4028      2496081               1  37.842088 -87.661032                  100
# 4029      2496392               1  37.844856 -87.665357                  100
#
#                  geofulladdress     geocity geostate   geozip    geocounty  \
# 0     11990 N COUNTY ROAD 550 W     DECATUR       IN    46733        ADAMS
# 1     1850 W COUNTY ROAD 1200 N     DECATUR       IN    46733        ADAMS
# 2       750 E COUNTY ROAD 900 N     DECATUR       IN    46733        ADAMS
# 3               7455 N PIQUA RD     DECATUR       IN    46733        ADAMS
# 4      2585 W COUNTY ROAD 750 N     DECATUR       IN    46733        ADAMS
# ...                         ...         ...      ...      ...          ...
# 4025         0 OLD HENDERSON RD  EVANSVILLE       IN    47712  VANDERBURGH
# 4026     15343 OLD HENDERSON RD  EVANSVILLE       IN  47712.0  VANDERBURGH
# 4027     15545 OLD HENDERSON RD  EVANSVILLE       IN  47712.0  VANDERBURGH
# 4028          14115 SEMINARY RD  EVANSVILLE       IN  47712.0  VANDERBURGH
# 4029          14133 SEMINARY RD  EVANSVILLE       IN  47712.0  VANDERBURGH
#
#              geobg10         geobg20
# 0     180010301001.0  180010301001.0
# 1     180010301002.0  180010301002.0
# 2     180010301004.0  180010301004.0
# 3     180010301004.0  180010301004.0
# 4     180010301002.0  180010301002.0
# ...              ...             ...
# 4025  181630104033.0  181630104061.0
# 4026  181630104033.0  181630104061.0
# 4027  181630104033.0  181630104061.0
# 4028  181630104033.0  181630104061.0
# 4029  181630104033.0  181630104061.0
#
# [4030 rows x 12 columns]

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('community_solar.db')
query = """
SELECT
    * 
FROM 
    LOCATIONS 
WHERE 
    has_solar_data = 2
"""
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#       location_id  has_solar_data   latitude  longitude  dlgf_prop_class_code  \
# 0         1351649               2  39.606029 -85.973397                   101
# 1         1351650               2  39.606214 -85.971796                   511
# 2         1351684               2  39.604123 -85.973405                   101
# 3         1363691               2  39.596650 -85.971106                   101
# 4         1364258               2  39.608076 -85.971845                   101
# ...           ...             ...        ...        ...                   ...
# 1108      1945505               2  41.424985 -87.070308                   510
# 1109      1945506               2  41.424967 -86.987914                   510
# 1110      1945507               2  41.425014 -86.986492                   510
# 1111      2251487               2  37.788321 -87.111485                   429
# 1112      2251488               2  37.787987 -87.111726                   429
#
#                 geofulladdress     geocity geostate geozip geocounty  \
# 0     8736 N COUNTY ROAD 700 E       ACTON       IN  46259   JOHNSON
# 1     8752 N COUNTY ROAD 700 E       ACTON       IN  46259   JOHNSON
# 2     8586 N COUNTY ROAD 700 E       ACTON       IN  46259   JOHNSON
# 3     7969 N COUNTY ROAD 700 E       ACTON       IN  46259   JOHNSON
# 4     8924 N COUNTY ROAD 700 E       ACTON       IN  46259   JOHNSON
# ...                        ...         ...      ...    ...       ...
# 1108              70 SHEILA LN  VALPARAISO       IN  46385    PORTER
# 1109          403 CREEKWOOD DR  VALPARAISO       IN  46383    PORTER
# 1110               62 NILES DR  VALPARAISO       IN  46383    PORTER
# 1111     6842 S STATE ROAD 161    ROCKPORT       IN  47635   SPENCER
# 1112     6842 S STATE ROAD 161    ROCKPORT       IN  47635   SPENCER
#
#              geobg10         geobg20
# 0     180816101001.0  180816101011.0
# 1     180816101001.0  180816101011.0
# 2     180816101001.0  180816101011.0
# 3     180816101002.0  180816101012.0
# 4     180816101001.0  180816101011.0
# ...              ...             ...
# 1108  181270510022.0  181270510101.0
# 1109  181270510022.0  181270510102.0
# 1110  181270510022.0  181270510102.0
# 1111  181479530002.0  181479530004.0
# 1112  181479530002.0  181479530004.0
#
# [1113 rows x 12 columns]

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('community_solar.db')
query = """
SELECT 
    location_id, latitude, longitude, has_solar_data
FROM 
    LOCATIONS 
WHERE 
    location_id NOT IN (SELECT location_id FROM GOOGLE_SOLAR) 
AND 
    has_solar_data = 0
AND 
    dlgf_prop_class_code LIKE '6%%'
"""
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#       location_id   latitude  longitude  has_solar_data
# 0         3074602  39.791413 -86.145262               0
# 1         3074610  39.834396 -86.001928               0
# 2         3074611  39.816039 -86.081824               0
# 3         3074614  39.815075 -86.082264               0
# 4         3074646  39.879468 -86.202615               0
# ...           ...        ...        ...             ...
# 9098      3291004  39.239337 -86.625291               0
# 9099      3291005  39.239337 -86.625291               0
# 9100      3291287  39.227452 -86.617584               0
# 9101      3291288  39.224624 -86.614133               0
# 9102      3291335  39.222248 -86.633656               0
#
# [9103 rows x 4 columns]

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('community_solar.db')
query = """
SELECT 
    *
FROM 
    PROPERTY_CODES
"""
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#     property_code_id property_code  \
# 0                  1           600
# 1                  2           610
# 2                  3           620
# 3                  4           621
# 4                  5           622
# 5                  6           630
# 6                  7           640
# 7                  8           645
# 8                  9           650
# 9                 10           660
# 10                11           661
# 11                12           662
# 12                13           665
# 13                14           669
# 14                15           670
# 15                16           680
# 16                17           685
# 17                18           686
# 18                19           690
# 19                20           699
#
#                                           description  \
# 0   EXEMPT PROPERTY OWNED BY THE UNITED STATES OF ...
# 1       EXEMPT PROPERTY OWNED BY THE STATE OF INDIANA
# 2                   EXEMPT PROPERTY OWNED BY A COUNTY
# 3      EXEMPT PROPERTY CERTIFIED FOR TREASURER’S SALE
# 4                     EXEMPT PROPERTY HELD FOR RESALE
# 5                 EXEMPT PROPERTY OWNED BY A TOWNSHIP
# 6             EXEMPT PROPERTY OWNED BY A MUNICIPALITY
# 7   EXEMPT PROPERTY OWNED BY A MUNICIPAL HOUSING A...
# 8       EXEMPT PROPERTY OWNED BY A BOARD OF EDUCATION
# 9            EXEMPT PROPERTY OWNED BY A PARK DISTRICT
# 10    EXEMPT PROPERTY OWNED BY A CONSERVANCY DISTRICT
# 11       EXEMPT PROPERTY OWNED BY A SANITARY DISTRICT
# 12          EXEMPT PROPERTY OWNED BY A PUBLIC LIBRARY
# 13  OTHER EXEMPT PROPERTY OWNED BY A GOVERNMENTAL ...
# 14  EXEMPT PROPERTY OWNED BY A PRIVATE ACADEMY OR ...
# 15  EXEMPT PROPERTY OWNED BY A CHARITABLE ORG THAT...
# 16  EXEMPT PROPERTY OWNED BY A RELIGIOUS ORG THAT ...
# 17  CHURCH, CHAPEL, MOSQUE, SYNAGOGUE, TABERNACLE,...
# 18  EXEMPT PROPERTY OWNED BY A CEMETERY ORG THAT I...
# 19  OTHER EXEMPT PROPERTY OWNED BY AN ORG THAT IS ...
#
#                                     name           date_added
# 0                Federal Exempt Property  2025-04-26 23:13:22
# 1                  State Exempt Property  2025-04-26 23:13:22
# 2                 County Exempt Property  2025-04-26 23:13:22
# 3         Treasurer-Sale Exempt Property  2025-04-26 23:13:22
# 4            Resale-Held Exempt Property  2025-04-26 23:13:22
# 5               Township Exempt Property  2025-04-26 23:13:22
# 6              Municipal Exempt Property  2025-04-26 23:13:22
# 7      Housing Authority Exempt Property  2025-04-26 23:13:22
# 8           School Board Exempt Property  2025-04-26 23:13:22
# 9          Park District Exempt Property  2025-04-26 23:13:22
# 10  Conservancy District Exempt Property  2025-04-26 23:13:22
# 11     Sanitary District Exempt Property  2025-04-26 23:13:22
# 12        Public Library Exempt Property  2025-04-26 23:13:22
# 13      Other Government Exempt Property  2025-04-26 23:13:22
# 14       Private Academy Exempt Property  2025-04-26 23:13:22
# 15        Charitable Org Exempt Property  2025-04-26 23:13:22
# 16         Religious Org Exempt Property  2025-04-26 23:13:22
# 17      Place of Worship Exempt Property  2025-04-26 23:13:22
# 18              Cemetery Exempt Property  2025-04-26 23:13:22
# 19       Other Nonprofit Exempt Property  2025-04-26 23:13:22

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('community_solar.db')
query = """
SELECT 
    location_id, latitude, longitude, has_solar_data
FROM 
    LOCATIONS 
WHERE 
    location_id IN (SELECT location_id FROM GOOGLE_SOLAR) 
AND 
    dlgf_prop_class_code LIKE '6%%'
"""
df = pd.read_sql_query(query, conn)
conn.close()
df
# Out:
#        location_id   latitude  longitude  has_solar_data
# 0            17074  40.947835 -85.167608               2
# 1            17155  40.948628 -85.167635               2
# 2            17542  40.954864 -85.224270               2
# 3            17665  40.959649 -85.281774               2
# 4            17673  40.959643 -85.216266               2
# ...            ...        ...        ...             ...
# 33386      2605505  37.948081 -87.405326               2
# 33387      2605507  37.946594 -87.412119               2
# 33388      2605515  37.947858 -87.413785               2
# 33389      2605547  37.947495 -87.414668               2
# 33390      2605587  37.947189 -87.406758               2
#
# [33391 rows x 4 columns]
