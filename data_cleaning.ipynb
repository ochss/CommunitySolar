# %%
import sqlite3
import pandas as pd
import requests
import json

# %%
conn = sqlite3.connect("community_solar.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('sqlite_sequence',), ('LOCATIONS',), ('NONPROFITS',), ('GOOGLE_SOLAR',)]

# %% [markdown]
# # Load Data

# %%
locations_query = "SELECT * FROM LOCATIONS WHERE dlgf_prop_class_code LIKE '6%'"
df_locations = pd.read_sql_query(locations_query, conn)
df_locations
# Out:
#        location_id                  X                 Y objectid  \
# 0               54      -84.927791301  40.8314136170001       54
# 1               85      -84.948219493      40.668662897       85
# 2               96  -84.9552047889999  40.7444441800001       96
# 3               97      -84.959462569  40.5901470150001       97
# 4              126  -84.9450544969999  40.8285533660001      126
# ...            ...                ...               ...      ...
# 93361      3291004      -86.625296197  39.2393445750001  3291004
# 93362      3291005      -86.625296197  39.2393445750001  3291005
# 93363      3291287      -86.617589653  39.2274599340001  3291287
# 93364      3291288      -86.614138372      39.224631903  3291288
# 93365      3291335      -86.633661488      39.222255332  3291335
#
#                           add_full addnum_pre add_number addnum_suf st_premod  \
# 0                   216 N FIFTH ST                 216.0
# 1                                                 1200.0
# 2                                                   30.0
# 3                                                  225.0
# 4                 1828 W MONROE ST                1828.0
# ...                            ...        ...        ...        ...       ...
# 93361  6151 N MATTHEWS DR UNIT 410                6151.0
# 93362  6151 N MATTHEWS DR UNIT 411                6151.0
# 93363      4616 N CAMPBELL PARK RD                4616.0
# 93364         4586 N HARTSTRAIT RD                4586.0
# 93365            4810 N ANGELA WAY                4810.0
#
#       st_predir  ... geostreettype   geounit       geocity geozip geostate  \
# 0         NORTH  ...            ST                 DECATUR  46733       IN
# 1                ...            RD                 DECATUR  46711       IN
# 2                ...                               DECATUR  46772       IN
# 3                ...            ST                 DECATUR  46740       IN
# 4          WEST  ...            ST                 DECATUR  46733       IN
# ...         ...  ...           ...       ...           ...    ...      ...
# 93361     NORTH  ...            DR  UNIT 410  ELLETTSVILLE  47429       IN
# 93362     NORTH  ...            DR  UNIT 411  ELLETTSVILLE  47429       IN
# 93363     NORTH  ...            RD            ELLETTSVILLE  47429       IN
# 93364     NORTH  ...            RD            ELLETTSVILLE  47429       IN
# 93365     NORTH  ...           WAY             BLOOMINGTON  47404       IN
#
#               geobg10         geobg20 geocounty geosufdir  \
# 0      180010303003.0  180010303003.0     ADAMS
# 1      180010306002.0  180010306002.0     ADAMS
# 2      180010305001.0  180010305001.0     ADAMS
# 3      180010307004.0  180010307004.0     ADAMS
# 4      180010302002.0  180010302002.0     ADAMS
# ...               ...             ...       ...       ...
# 93361  181050013031.0  181050013031.0    MONROE
# 93362  181050013031.0  181050013031.0    MONROE
# 93363  181050013043.0  181050013043.0    MONROE
# 93364  181050013043.0  181050013051.0    MONROE
# 93365  181050013041.0  181050013041.0    MONROE
#
#                                                 user_fld
# 0      ADAMS;18001;180010303003;180010303003;01050320...
# 1      ADAMS;18001;180010306002;180010306002;01083310...
# 2      ADAMS;18001;180010305001;180010305001;01080410...
# 3      ADAMS;18001;180010307004;180010307004;01112940...
# 4      ADAMS;18001;180010302002;180010302002;01050420...
# ...                                                  ...
# 93361  MONROE;18105;181050013031;181050013031;5304033...
# 93362  MONROE;18105;181050013031;181050013031;5304033...
# 93363  MONROE;18105;181050013043;181050013043;5304104...
# 93364  MONROE;18105;181050013043;181050013051;5304104...
# 93365  MONROE;18105;181050013041;181050013041;5304161...
#
# [93366 rows x 62 columns]

# %%
nonprofits_query = "SELECT * FROM NONPROFITS WHERE source_agency == 'SOS'"
df_nonprofits = pd.read_sql_query(nonprofits_query, conn)
df_nonprofits
# Out:
#                                                comp_name  \
# 0                      Ac Football Booster Club, Inc. ()
# 1                 Adams Central Character Academy Inc ()
# 2      Adams Central Elementary School Building Corpo...
# 3            Adams Central Flag Football League, Inc. ()
# 4                Adams Central Golf Booster Club, Inc ()
# ...                                                  ...
# 40029              Wild At Heart Wildlife Rehab, Inc. ()
# 40030                      Wildcat Booster Club, Inc. ()
# 40031           Wishbone Orthopaedic Foundation, Inc. ()
# 40032                       World Wagyu Council, Inc. ()
# 40033                    Worship 995 Ministries, Inc. ()
#
#                       address1           CITY    ZIP  contact_name  \
# 0                 113 N 2Nd St        Decatur  46733
# 1                   Po Box 121         Monroe  46772
# 2          C/O Audra S. Snyder        Decatur  46733  Steve Stucky
# 3               3202 N. 700 E.        Decatur  46733
# 4               235 Harvest Ln         Monroe  46772
# ...                        ...            ...    ...           ...
# 40029         408 Arrowhead Ct  Columbia City  46725
# 40030        1 Big Blue Avenue  South Whitley  46787
# 40031  1560 North State Road 5        Larwill  46764
# 40032      6755 East 900 North  Columbia City  46725
# 40033           8901 Mccomb Rd     Churubusco  46723
#
#       source_agency   county
# 0               SOS    Adams
# 1               SOS    Adams
# 2               SOS    Adams
# 3               SOS    Adams
# 4               SOS    Adams
# ...             ...      ...
# 40029           SOS  Whitley
# 40030           SOS  Whitley
# 40031           SOS  Whitley
# 40032           SOS  Whitley
# 40033           SOS  Whitley
#
# [40034 rows x 7 columns]

# %%
google_solar_query = "SELECT * FROM GOOGLE_SOLAR"
df_google_solar = pd.read_sql_query(google_solar_query, conn)
df_google_solar
# Out:
#    solar_id  location_id   latitude  longitude  max_panel_count  \
# 0         1        26769  41.018635 -85.167521               53
#
#    yearly_energy_production           date_added
# 0                 20784.182  2025-04-06 02:29:54

# %% [markdown]
# # Analyze Data

# %% [markdown]
# ## Raw Analysis

# %%
df_locations["dlgf_prop_class_code"].value_counts()
# Out:
# dlgf_prop_class_code
# 640    19081
# 680    14273
# 685    12047
# 699    11159
# 686     9147
# 610     5103
# 620     4226
# 650     4125
# 645     4005
# 670     3595
# 630     2031
# 690     1183
# 600     1116
# 660      872
# 661      404
# 669      359
# 665      340
# 662      265
# 622       35
# Name: count, dtype: int64

# %%
df_locations["geocounty"].nunique()
# Out:
# 92

# %%
df_locations["geocity"].nunique()
# Out:
# 696

# %%
len(df_locations) / df_locations["geocounty"].nunique()
# Out:
# 1014.8478260869565

# %%
len(df_locations) / df_locations["geocity"].nunique()
# Out:
# 134.14655172413794

# %%
for col in df_locations:
    print(col)
    nan_count = df_locations[col].isna().sum()
    empty_string_count = (df_locations[col] == "").sum() if df_locations[col].dtype == "object" else 0
    print(f"NaNs: {nan_count}, Empty strings: {empty_string_count}")
    print()
# Out:
# location_id
# NaNs: 0, Empty strings: 0
#
# X
# NaNs: 0, Empty strings: 0
#
# Y
# NaNs: 0, Empty strings: 0
#
# objectid
# NaNs: 0, Empty strings: 0
#
# add_full
# NaNs: 0, Empty strings: 30984
#
# addnum_pre
# NaNs: 0, Empty strings: 93350
#
# add_number
# NaNs: 0, Empty strings: 2893
#
# addnum_suf
# NaNs: 0, Empty strings: 92410
#
# st_premod
# NaNs: 0, Empty strings: 93123
#
# st_predir
# NaNs: 0, Empty strings: 45147
#
# st_pretyp
# NaNs: 0, Empty strings: 83994
#
# st_presep
# NaNs: 0, Empty strings: 93361
#
# st_name
# NaNs: 0, Empty strings: 543
#
# st_postyp
# NaNs: 0, Empty strings: 12522
#
# st_posdir
# NaNs: 0, Empty strings: 86529
#
# st_posmod
# NaNs: 0, Empty strings: 93287
#
# unit
# NaNs: 0, Empty strings: 80243
#
# floor
# NaNs: 0, Empty strings: 92793
#
# esn
# NaNs: 0, Empty strings: 74596
#
# msagcomm
# NaNs: 0, Empty strings: 77967
#
# inc_muni
# NaNs: 0, Empty strings: 63091
#
# uninc_comm
# NaNs: 0, Empty strings: 88610
#
# post_comm
# NaNs: 0, Empty strings: 13945
#
# post_code
# NaNs: 0, Empty strings: 21057
#
# county
# NaNs: 0, Empty strings: 45027
#
# placement
# NaNs: 0, Empty strings: 81780
#
# state_parcel_id
# NaNs: 0, Empty strings: 61038
#
# local_id
# NaNs: 0, Empty strings: 0
#
# nguid
# NaNs: 0, Empty strings: 0
#
# state
# NaNs: 0, Empty strings: 0
#
# source_datadesc
# NaNs: 0, Empty strings: 0
#
# source_datasetid
# NaNs: 0, Empty strings: 0
#
# source_featureid
# NaNs: 0, Empty strings: 0
#
# source_originator
# NaNs: 0, Empty strings: 0
#
# loaddate
# NaNs: 0, Empty strings: 0
#
# county_fips
# NaNs: 0, Empty strings: 0
#
# county_id
# NaNs: 0, Empty strings: 0
#
# esri_zip
# NaNs: 0, Empty strings: 0
#
# esri_poname
# NaNs: 0, Empty strings: 0
#
# dlgf_prop_address
# NaNs: 0, Empty strings: 34
#
# dlgf_prop_address_city
# NaNs: 0, Empty strings: 938
#
# dlgf_prop_address_zip
# NaNs: 0, Empty strings: 267
#
# dlgf_prop_class_code
# NaNs: 0, Empty strings: 0
#
# join_state_parcel_id
# NaNs: 0, Empty strings: 0
#
# latitude
# NaNs: 0, Empty strings: 0
#
# longitude
# NaNs: 0, Empty strings: 0
#
# orig_addr
# NaNs: 0, Empty strings: 1145
#
# geofulladdress
# NaNs: 0, Empty strings: 103
#
# geohousenum
# NaNs: 0, Empty strings: 3066
#
# geopredir
# NaNs: 0, Empty strings: 45147
#
# geopretype
# NaNs: 0, Empty strings: 84035
#
# geostreetname
# NaNs: 0, Empty strings: 543
#
# geostreettype
# NaNs: 0, Empty strings: 12522
#
# geounit
# NaNs: 0, Empty strings: 80285
#
# geocity
# NaNs: 0, Empty strings: 0
#
# geozip
# NaNs: 0, Empty strings: 0
#
# geostate
# NaNs: 0, Empty strings: 0
#
# geobg10
# NaNs: 0, Empty strings: 0
#
# geobg20
# NaNs: 0, Empty strings: 0
#
# geocounty
# NaNs: 0, Empty strings: 0
#
# geosufdir
# NaNs: 0, Empty strings: 86540
#
# user_fld
# NaNs: 0, Empty strings: 0

# %% [markdown]
# ## Select Columns

# %%
df_locations_selected = df_locations[[
    "location_id", 
    "dlgf_prop_class_code",
    "latitude", 
    "longitude", 
    "dlgf_prop_address", 
    "dlgf_prop_address_city",
    "dlgf_prop_address_zip",
    "geofulladdress",
    "geocity",
    "geozip",
    "geostate",
    "geobg10",
    "geobg20",
    "geocounty"
]]

df_locations_selected
# Out:
#        location_id  dlgf_prop_class_code   latitude  longitude  \
# 0               54                   680  40.831414 -84.927791
# 1               85                   680  40.668663 -84.948219
# 2               96                   610  40.744444 -84.955205
# 3               97                   685  40.590147 -84.959463
# 4              126                   690  40.828553 -84.945054
# ...            ...                   ...        ...        ...
# 93361      3291004                   699  39.239337 -86.625291
# 93362      3291005                   699  39.239337 -86.625291
# 93363      3291287                   640  39.227452 -86.617584
# 93364      3291288                   640  39.224624 -86.614133
# 93365      3291335                   640  39.222248 -86.633656
#
#                dlgf_prop_address dlgf_prop_address_city dlgf_prop_address_zip  \
# 0                   216 N 5TH ST                DECATUR            46733-0000
# 1                 1100 SWISS WAY                  BERNE            46711-0000
# 2             30 S US HIGHWAY 27                 MONROE            46772-0000
# 3                 235 DECATUR ST                 GENEVA            46740-0000
# 4               1824 W MONROE ST                DECATUR            46733-0000
# ...                          ...                    ...                   ...
# 93361         6151 N MATTHEWS DR
# 93362         6151 N MATTHEWS DR
# 93363  4616 N CAMPBELL'S PARK RD
# 93364  4616 N CAMPBELL'S PARK RD
# 93365          4810 N ANGELA WAY
#
#                     geofulladdress       geocity geozip geostate  \
# 0                   216 N FIFTH ST       DECATUR  46733       IN
# 1                 1200 SWISSWAY RD       DECATUR  46711       IN
# 2      30 UNITED STATES HIGHWAY 27       DECATUR  46772       IN
# 3                   225 DECATUR ST       DECATUR  46740       IN
# 4                 1828 W MONROE ST       DECATUR  46733       IN
# ...                            ...           ...    ...      ...
# 93361  6151 N MATTHEWS DR UNIT 410  ELLETTSVILLE  47429       IN
# 93362  6151 N MATTHEWS DR UNIT 411  ELLETTSVILLE  47429       IN
# 93363      4616 N CAMPBELL PARK RD  ELLETTSVILLE  47429       IN
# 93364         4586 N HARTSTRAIT RD  ELLETTSVILLE  47429       IN
# 93365            4810 N ANGELA WAY   BLOOMINGTON  47404       IN
#
#               geobg10         geobg20 geocounty
# 0      180010303003.0  180010303003.0     ADAMS
# 1      180010306002.0  180010306002.0     ADAMS
# 2      180010305001.0  180010305001.0     ADAMS
# 3      180010307004.0  180010307004.0     ADAMS
# 4      180010302002.0  180010302002.0     ADAMS
# ...               ...             ...       ...
# 93361  181050013031.0  181050013031.0    MONROE
# 93362  181050013031.0  181050013031.0    MONROE
# 93363  181050013043.0  181050013043.0    MONROE
# 93364  181050013043.0  181050013051.0    MONROE
# 93365  181050013041.0  181050013041.0    MONROE
#
# [93366 rows x 14 columns]

# %%
df_locations_selected.drop_duplicates(subset = ["latitude", "longitude"])
# Out:
#        location_id  dlgf_prop_class_code   latitude  longitude  \
# 0               54                   680  40.831414 -84.927791
# 1               85                   680  40.668663 -84.948219
# 2               96                   610  40.744444 -84.955205
# 3               97                   685  40.590147 -84.959463
# 4              126                   690  40.828553 -84.945054
# ...            ...                   ...        ...        ...
# 93311      3290737                   640  39.230415 -86.618630
# 93312      3290955                   650  39.234818 -86.634091
# 93363      3291287                   640  39.227452 -86.617584
# 93364      3291288                   640  39.224624 -86.614133
# 93365      3291335                   640  39.222248 -86.633656
#
#                dlgf_prop_address dlgf_prop_address_city dlgf_prop_address_zip  \
# 0                   216 N 5TH ST                DECATUR            46733-0000
# 1                 1100 SWISS WAY                  BERNE            46711-0000
# 2             30 S US HIGHWAY 27                 MONROE            46772-0000
# 3                 235 DECATUR ST                 GENEVA            46740-0000
# 4               1824 W MONROE ST                DECATUR            46733-0000
# ...                          ...                    ...                   ...
# 93311  4616 N CAMPBELL'S PARK RD
# 93312          601 S EDGEWOOD DR
# 93363  4616 N CAMPBELL'S PARK RD
# 93364  4616 N CAMPBELL'S PARK RD
# 93365          4810 N ANGELA WAY
#
#                     geofulladdress       geocity geozip geostate  \
# 0                   216 N FIFTH ST       DECATUR  46733       IN
# 1                 1200 SWISSWAY RD       DECATUR  46711       IN
# 2      30 UNITED STATES HIGHWAY 27       DECATUR  46772       IN
# 3                   225 DECATUR ST       DECATUR  46740       IN
# 4                 1828 W MONROE ST       DECATUR  46733       IN
# ...                            ...           ...    ...      ...
# 93311                301 E VINE ST  ELLETTSVILLE  47429       IN
# 93312            550 S EDGEWOOD DR  ELLETTSVILLE  47429       IN
# 93363      4616 N CAMPBELL PARK RD  ELLETTSVILLE  47429       IN
# 93364         4586 N HARTSTRAIT RD  ELLETTSVILLE  47429       IN
# 93365            4810 N ANGELA WAY   BLOOMINGTON  47404       IN
#
#               geobg10         geobg20 geocounty
# 0      180010303003.0  180010303003.0     ADAMS
# 1      180010306002.0  180010306002.0     ADAMS
# 2      180010305001.0  180010305001.0     ADAMS
# 3      180010307004.0  180010307004.0     ADAMS
# 4      180010302002.0  180010302002.0     ADAMS
# ...               ...             ...       ...
# 93311  181050013032.0  181050013032.0    MONROE
# 93312  181050013042.0  181050013042.0    MONROE
# 93363  181050013043.0  181050013043.0    MONROE
# 93364  181050013043.0  181050013051.0    MONROE
# 93365  181050013041.0  181050013041.0    MONROE
#
# [90232 rows x 14 columns]

# %% [markdown]
# ## Column Comparison

# %%
df_locations_selected[df_locations_selected["dlgf_prop_address"] != df_locations_selected["geofulladdress"]]
# Out:
#        location_id  dlgf_prop_class_code   latitude  longitude  \
# 0               54                   680  40.831414 -84.927791
# 1               85                   680  40.668663 -84.948219
# 2               96                   610  40.744444 -84.955205
# 3               97                   685  40.590147 -84.959463
# 4              126                   690  40.828553 -84.945054
# ...            ...                   ...        ...        ...
# 93360      3291003                   699  39.239337 -86.625291
# 93361      3291004                   699  39.239337 -86.625291
# 93362      3291005                   699  39.239337 -86.625291
# 93363      3291287                   640  39.227452 -86.617584
# 93364      3291288                   640  39.224624 -86.614133
#
#                dlgf_prop_address dlgf_prop_address_city dlgf_prop_address_zip  \
# 0                   216 N 5TH ST                DECATUR            46733-0000
# 1                 1100 SWISS WAY                  BERNE            46711-0000
# 2             30 S US HIGHWAY 27                 MONROE            46772-0000
# 3                 235 DECATUR ST                 GENEVA            46740-0000
# 4               1824 W MONROE ST                DECATUR            46733-0000
# ...                          ...                    ...                   ...
# 93360         6151 N MATTHEWS DR
# 93361         6151 N MATTHEWS DR
# 93362         6151 N MATTHEWS DR
# 93363  4616 N CAMPBELL'S PARK RD
# 93364  4616 N CAMPBELL'S PARK RD
#
#                     geofulladdress       geocity geozip geostate  \
# 0                   216 N FIFTH ST       DECATUR  46733       IN
# 1                 1200 SWISSWAY RD       DECATUR  46711       IN
# 2      30 UNITED STATES HIGHWAY 27       DECATUR  46772       IN
# 3                   225 DECATUR ST       DECATUR  46740       IN
# 4                 1828 W MONROE ST       DECATUR  46733       IN
# ...                            ...           ...    ...      ...
# 93360  6151 N MATTHEWS DR UNIT 409  ELLETTSVILLE  47429       IN
# 93361  6151 N MATTHEWS DR UNIT 410  ELLETTSVILLE  47429       IN
# 93362  6151 N MATTHEWS DR UNIT 411  ELLETTSVILLE  47429       IN
# 93363      4616 N CAMPBELL PARK RD  ELLETTSVILLE  47429       IN
# 93364         4586 N HARTSTRAIT RD  ELLETTSVILLE  47429       IN
#
#               geobg10         geobg20 geocounty
# 0      180010303003.0  180010303003.0     ADAMS
# 1      180010306002.0  180010306002.0     ADAMS
# 2      180010305001.0  180010305001.0     ADAMS
# 3      180010307004.0  180010307004.0     ADAMS
# 4      180010302002.0  180010302002.0     ADAMS
# ...               ...             ...       ...
# 93360  181050013031.0  181050013031.0    MONROE
# 93361  181050013031.0  181050013031.0    MONROE
# 93362  181050013031.0  181050013031.0    MONROE
# 93363  181050013043.0  181050013043.0    MONROE
# 93364  181050013043.0  181050013051.0    MONROE
#
# [65703 rows x 14 columns]

# %%
df_locations_selected[df_locations_selected["geobg10"] != df_locations_selected["geobg20"]]
# Out:
#        location_id  dlgf_prop_class_code   latitude  longitude  \
# 133           2962                   680  40.810498 -84.916680
# 286           7452                   685  40.592243 -84.957638
# 287           7453                   685  40.592244 -84.957680
# 296           7597                   640  40.592408 -84.957939
# 298           7690                   680  40.592307 -84.961406
# ...            ...                   ...        ...        ...
# 93130      3287322                   680  39.312795 -86.627884
# 93131      3287354                   630  39.164173 -86.606234
# 93132      3287420                   685  39.209808 -86.618721
# 93213      3288096                   640  39.264978 -86.626904
# 93364      3291288                   640  39.224624 -86.614133
#
#                dlgf_prop_address dlgf_prop_address_city dlgf_prop_address_zip  \
# 133                 1703 HIGH ST                DECATUR            46733-0000
# 286                415 E LINE ST                 GENEVA            46740-0000
# 287                415 E LINE ST                 GENEVA            46740-0000
# 296                  105 HIGH ST                 GENEVA            46740-0000
# 298                105 W LINE ST                 GENEVA            46740-0000
# ...                          ...                    ...                   ...
# 93130           9195 N BOTTOM RD           ELLETTSVILLE            47429-0000
# 93131      352 S FIELDSTONE BLVD            BLOOMINGTON            47404-0000
# 93132          6287 W RATLIFF RD
# 93213         7568 N RED HILL RD
# 93364  4616 N CAMPBELL'S PARK RD
#
#               geofulladdress       geocity geozip geostate         geobg10  \
# 133             1619 HIGH ST       DECATUR  46733       IN  180010303005.0
# 286            417 E LINE ST       DECATUR  46740       IN  180010307004.0
# 287            415 E LINE ST       DECATUR  46740       IN  180010307004.0
# 296              105 HIGH ST       DECATUR  46740       IN  180010307004.0
# 298            105 W LINE ST        GENEVA  46740       IN  180010307004.0
# ...                      ...           ...    ...      ...             ...
# 93130       9195 N BOTTOM RD  ELLETTSVILLE  47429       IN  181050013011.0
# 93131  352 S FIELDSTONE BLVD   BLOOMINGTON  47404       IN  181050005013.0
# 93132      6287 W RATLIFF RD   BLOOMINGTON  47404       IN  181050013014.0
# 93213     7568 N RED HILL RD  ELLETTSVILLE  47429       IN  181050013011.0
# 93364   4586 N HARTSTRAIT RD  ELLETTSVILLE  47429       IN  181050013043.0
#
#               geobg20 geocounty
# 133    180010303006.0     ADAMS
# 286    180010307003.0     ADAMS
# 287    180010307003.0     ADAMS
# 296    180010307003.0     ADAMS
# 298    180010307003.0     ADAMS
# ...               ...       ...
# 93130  181050013014.0    MONROE
# 93131  181050005012.0    MONROE
# 93132  181050013013.0    MONROE
# 93213  181050013015.0    MONROE
# 93364  181050013051.0    MONROE
#
# [29669 rows x 14 columns]

# %% [markdown]
# # Google Solar API

# %%
def get_solar_data(api_key, latitude, longitude):
    api_url = f"https://solar.googleapis.com/v1/buildingInsights:findClosest?location.latitude={latitude}&location.longitude={longitude}&requiredQuality=HIGH&key={api_key}"
    response = requests.get(api_url)
    solar_data = response.json()
    if response.status_code != 200:
        print(f"Error fetching data: {response.status_code}")
    else:
        print("Data fetched successfully")
        with open(f"solar_data_{latitude}_{longitude}.json", "w") as f:
            json.dump(solar_data, f, indent=4)
        return solar_data

def process_solar_data(solar_data):
    try:
        solar_potential = solar_data.get("solarPotential", {})
        solar_configs = solar_potential.get("solarPanelConfigs", [])
        best_config = max(solar_configs, key = lambda c: c.get("yearlyEnergyDcKwh", 0)) if solar_configs else {}
        
        # Core fields
        panel_count = solar_potential.get("maxArrayPanelsCount", 0)
        panel_watts = solar_potential.get("panelCapacityWatts", 300)
        carbon_offset_factor = solar_potential.get("carbonOffsetFactorKgPerMwh", 0)
        imagery_quality = solar_data.get("imageryQuality", "UNKNOWN")
        
        # Imagery date
        imagery_date_info = solar_data.get("imageryDate")
        if imagery_date_info:
            try:
                year = imagery_date_info["year"]
                month = imagery_date_info["month"]
                day = imagery_date_info["day"]
                imagery_date = f"{month:02d}-{day:02d}-{year:04d}"
            except (KeyError, TypeError, ValueError):
                imagery_date = None
        else:
            imagery_date = None
        
        # Derived metrics
        nominal_power_watts = panel_count * panel_watts
        yearly_energy_kwh = best_config.get("yearlyEnergyDcKwh")
        
        # Fallback: estimate energy using whole sun quant (if available)
        if not yearly_energy_kwh:
            whole_sun_quant = solar_potential.get("maxSunshineHoursPerYear", 1000)
            estimated_kwh = (nominal_power_watts / 1000) * whole_sun_quant * 0.8
            yearly_energy_kwh = round(estimated_kwh, 2)
        
        # CO2 savings in tons based on EPA estimate
        co2_savings_tons = yearly_energy_kwh * 0.000699
        
        # Houses powered (based on US average usage)
        houses_powered = round(yearly_energy_kwh / 10566, 2)
        
        return {
            "imageryQuality": imagery_quality,
            "imageryDate": imagery_date,
            "maxArrayPanelsCount": panel_count,
            "panelCapacityWatts": panel_watts,
            "nominalPowerWatts": nominal_power_watts, # Manual
            "yearlyEnergyDcKwh": yearly_energy_kwh,
            "carbonOffsetFactorKgPerMwh": carbon_offset_factor,
            "estimatedAnnualCO2SavingsTons": round(co2_savings_tons, 2), # Manual
            "estimatedHousesPowered": houses_powered # Manual
        }
    
    except KeyError:
        print(f"Missing field in response: {e}")
        return None

# %%
process_solar_data(get_solar_data("AIzaSyAuFCqbjjsG9LGJeeR57PA0KdrfXIr5pbw", 39.164173, -86.606234))
# Out:
# Data fetched successfully
# {'imageryQuality': 'HIGH',
#  'imageryDate': '09-21-2016',
#  'maxArrayPanelsCount': 51,
#  'panelCapacityWatts': 400,
#  'nominalPowerWatts': 20400,
#  'yearlyEnergyDcKwh': 24112.436,
#  'carbonOffsetFactorKgPerMwh': 883.09717,
#  'estimatedAnnualCO2SavingsTons': 16.85,
#  'estimatedHousesPowered': 2.28}

# %%
process_solar_data(get_solar_data("AIzaSyAuFCqbjjsG9LGJeeR57PA0KdrfXIr5pbw", 39.264978, -86.626904))
# Out:
# Error fetching data: 404
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 process_solar_data(get_solar_data("AIzaSyAuFCqbjjsG9LGJeeR57PA0KdrfXIr5pbw", 39.264978, -86.626904))
#
# Cell In[81], line 15, in process_solar_data(solar_data)
#      13 def process_solar_data(solar_data):
#      14     try:
# ---> 15         solar_potential = solar_data.get("solarPotential", {})
#      16         solar_configs = solar_potential.get("solarPanelConfigs", [])
#      17         best_config = max(solar_configs, key = lambda c: c.get("yearlyEnergyDcKwh", 0)) if solar_configs else {}
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
process_solar_data(get_solar_data("AIzaSyAuFCqbjjsG9LGJeeR57PA0KdrfXIr5pbw", 41.018635, -85.167521))
# Out:
# Data fetched successfully
# {'imageryQuality': 'HIGH',
#  'imageryDate': '09-15-2015',
#  'maxArrayPanelsCount': 53,
#  'panelCapacityWatts': 400,
#  'nominalPowerWatts': 21200,
#  'yearlyEnergyDcKwh': 20784.182,
#  'carbonOffsetFactorKgPerMwh': 883.09717,
#  'estimatedAnnualCO2SavingsTons': 14.53,
#  'estimatedHousesPowered': 1.97}

# %%
get_solar_data("AIzaSyAuFCqbjjsG9LGJeeR57PA0KdrfXIr5pbw", 41.018635, -85.167521)
# Out:
# Data fetched successfully
# {'name': 'buildings/ChIJG9oTGWDvFYgRB89SoyFwMdI',
#  'center': {'latitude': 41.018527, 'longitude': -85.1675944},
#  'imageryDate': {'year': 2015, 'month': 9, 'day': 15},
#  'postalCode': '46819',
#  'administrativeArea': 'IN',
#  'statisticalArea': '18003003901',
#  'regionCode': 'US',
#  'solarPotential': {'maxArrayPanelsCount': 53,
#   'maxArrayAreaMeters2': 104.068405,
#   'maxSunshineHoursPerYear': 1220.6074,
#   'carbonOffsetFactorKgPerMwh': 883.09717,
#   'wholeRoofStats': {'areaMeters2': 120.9026,
#    'sunshineQuantiles': [376.46213,
#     716.7738,
#     891.9591,
#     938.937,
#     958.9749,
#     980.3871,
#     999.67896,
#     1016.5496,
#     1039.6727,
#     1092.4525,
#     1346.6733],
#    'groundAreaMeters2': 84.36},
#   'roofSegmentStats': [{'pitchDegrees': 45.861034,
#     'azimuthDegrees': 268.66965,
#     'stats': {'areaMeters2': 63.483536,
#      'sunshineQuantiles': [376.46213,
#       749.76294,
#       912.68585,
#       958.05383,
#       981.75885,
#       1001.2915,
#       1016.0894,
#       1032.4211,
#       1060.4766,
#       1113.5778,
#       1346.6733],
#      'groundAreaMeters2': 44.21},
#     'center': {'latitude': 41.018527399999996, 'longitude': -85.1676193},
#     'boundingBox': {'sw': {'latitude': 41.018482399999996,
#       'longitude': -85.1676509},
#      'ne': {'latitude': 41.0185733, 'longitude': -85.1675913}},
#     'planeHeightAtCenterMeters': 245.79625},
#    {'pitchDegrees': 45.63353,
#     'azimuthDegrees': 88.49446,
#     'stats': {'areaMeters2': 57.419064,
#      'sunshineQuantiles': [424.09525,
#       694.5262,
#       877.71075,
#       920.6433,
#       944.32306,
#       958.0978,
#       977.185,
#       995.38715,
#       1015.59973,
#       1051.7813,
#       1333.3112],
#      'groundAreaMeters2': 40.15},
#     'center': {'latitude': 41.0185248, 'longitude': -85.1675683},
#     'boundingBox': {'sw': {'latitude': 41.0184815,
#       'longitude': -85.16759379999999},
#      'ne': {'latitude': 41.0185706, 'longitude': -85.1675379}},
#     'planeHeightAtCenterMeters': 245.91722}],
#   'solarPanelConfigs': [{'panelsCount': 4,
#     'yearlyEnergyDcKwh': 1794.3337,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 4,
#       'yearlyEnergyDcKwh': 1794.3337,
#       'segmentIndex': 0}]},
#    {'panelsCount': 5,
#     'yearlyEnergyDcKwh': 2227.3064,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2227.3064,
#       'segmentIndex': 0}]},
#    {'panelsCount': 6,
#     'yearlyEnergyDcKwh': 2660.4163,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 6,
#       'yearlyEnergyDcKwh': 2660.4163,
#       'segmentIndex': 0}]},
#    {'panelsCount': 7,
#     'yearlyEnergyDcKwh': 3092.8435,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 3092.8435,
#       'segmentIndex': 0}]},
#    {'panelsCount': 8,
#     'yearlyEnergyDcKwh': 3523.6846,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 8,
#       'yearlyEnergyDcKwh': 3523.6843,
#       'segmentIndex': 0}]},
#    {'panelsCount': 9,
#     'yearlyEnergyDcKwh': 3950.079,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 8,
#       'yearlyEnergyDcKwh': 3523.6843,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 1,
#       'yearlyEnergyDcKwh': 426.39465,
#       'segmentIndex': 1}]},
#    {'panelsCount': 10,
#     'yearlyEnergyDcKwh': 4372.053,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 8,
#       'yearlyEnergyDcKwh': 3523.6843,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 2,
#       'yearlyEnergyDcKwh': 848.3688,
#       'segmentIndex': 1}]},
#    {'panelsCount': 11,
#     'yearlyEnergyDcKwh': 4793.2974,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 9,
#       'yearlyEnergyDcKwh': 3944.9282,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 2,
#       'yearlyEnergyDcKwh': 848.3688,
#       'segmentIndex': 1}]},
#    {'panelsCount': 12,
#     'yearlyEnergyDcKwh': 5214.5146,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 9,
#       'yearlyEnergyDcKwh': 3944.9282,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 3,
#       'yearlyEnergyDcKwh': 1269.5863,
#       'segmentIndex': 1}]},
#    {'panelsCount': 13,
#     'yearlyEnergyDcKwh': 5634.34,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 9,
#       'yearlyEnergyDcKwh': 3944.9282,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 4,
#       'yearlyEnergyDcKwh': 1689.4113,
#       'segmentIndex': 1}]},
#    {'panelsCount': 14,
#     'yearlyEnergyDcKwh': 6051.236,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 9,
#       'yearlyEnergyDcKwh': 3944.9282,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2106.3074,
#       'segmentIndex': 1}]},
#    {'panelsCount': 15,
#     'yearlyEnergyDcKwh': 6466.5034,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 10,
#       'yearlyEnergyDcKwh': 4360.196,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2106.3074,
#       'segmentIndex': 1}]},
#    {'panelsCount': 16,
#     'yearlyEnergyDcKwh': 6881.422,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 11,
#       'yearlyEnergyDcKwh': 4775.1143,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2106.3074,
#       'segmentIndex': 1}]},
#    {'panelsCount': 17,
#     'yearlyEnergyDcKwh': 7295.639,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 12,
#       'yearlyEnergyDcKwh': 5189.3315,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2106.3074,
#       'segmentIndex': 1}]},
#    {'panelsCount': 18,
#     'yearlyEnergyDcKwh': 7704.649,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 13,
#       'yearlyEnergyDcKwh': 5598.3413,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 5,
#       'yearlyEnergyDcKwh': 2106.3074,
#       'segmentIndex': 1}]},
#    {'panelsCount': 19,
#     'yearlyEnergyDcKwh': 8113.2314,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 13,
#       'yearlyEnergyDcKwh': 5598.3413,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 6,
#       'yearlyEnergyDcKwh': 2514.89,
#       'segmentIndex': 1}]},
#    {'panelsCount': 20,
#     'yearlyEnergyDcKwh': 8519.727,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 14,
#       'yearlyEnergyDcKwh': 6004.8364,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 6,
#       'yearlyEnergyDcKwh': 2514.89,
#       'segmentIndex': 1}]},
#    {'panelsCount': 21,
#     'yearlyEnergyDcKwh': 8922.749,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 14,
#       'yearlyEnergyDcKwh': 6004.8364,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 22,
#     'yearlyEnergyDcKwh': 9324.72,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 15,
#       'yearlyEnergyDcKwh': 6406.807,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 23,
#     'yearlyEnergyDcKwh': 9720.911,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 16,
#       'yearlyEnergyDcKwh': 6802.999,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 24,
#     'yearlyEnergyDcKwh': 10115.875,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 17,
#       'yearlyEnergyDcKwh': 7197.9624,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 25,
#     'yearlyEnergyDcKwh': 10510.829,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 18,
#       'yearlyEnergyDcKwh': 7592.9165,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 26,
#     'yearlyEnergyDcKwh': 10905.671,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 19,
#       'yearlyEnergyDcKwh': 7987.7583,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 27,
#     'yearlyEnergyDcKwh': 11300.495,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 20,
#       'yearlyEnergyDcKwh': 8382.583,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 7,
#       'yearlyEnergyDcKwh': 2917.9124,
#       'segmentIndex': 1}]},
#    {'panelsCount': 28,
#     'yearlyEnergyDcKwh': 11694.612,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 20,
#       'yearlyEnergyDcKwh': 8382.583,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 8,
#       'yearlyEnergyDcKwh': 3312.0295,
#       'segmentIndex': 1}]},
#    {'panelsCount': 29,
#     'yearlyEnergyDcKwh': 12088.484,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8776.455,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 8,
#       'yearlyEnergyDcKwh': 3312.0295,
#       'segmentIndex': 1}]},
#    {'panelsCount': 30,
#     'yearlyEnergyDcKwh': 12481.473,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8776.455,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 9,
#       'yearlyEnergyDcKwh': 3705.017,
#       'segmentIndex': 1}]},
#    {'panelsCount': 31,
#     'yearlyEnergyDcKwh': 12873.275,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8776.455,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 10,
#       'yearlyEnergyDcKwh': 4096.82,
#       'segmentIndex': 1}]},
#    {'panelsCount': 32,
#     'yearlyEnergyDcKwh': 13263.942,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8776.455,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 11,
#       'yearlyEnergyDcKwh': 4487.487,
#       'segmentIndex': 1}]},
#    {'panelsCount': 33,
#     'yearlyEnergyDcKwh': 13654.199,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8776.455,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 12,
#       'yearlyEnergyDcKwh': 4877.7437,
#       'segmentIndex': 1}]},
#    {'panelsCount': 34,
#     'yearlyEnergyDcKwh': 14041.409,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 22,
#       'yearlyEnergyDcKwh': 9163.665,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 12,
#       'yearlyEnergyDcKwh': 4877.7437,
#       'segmentIndex': 1}]},
#    {'panelsCount': 35,
#     'yearlyEnergyDcKwh': 14428.575,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 22,
#       'yearlyEnergyDcKwh': 9163.665,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 13,
#       'yearlyEnergyDcKwh': 5264.909,
#       'segmentIndex': 1}]},
#    {'panelsCount': 36,
#     'yearlyEnergyDcKwh': 14814.496,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 23,
#       'yearlyEnergyDcKwh': 9549.586,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 13,
#       'yearlyEnergyDcKwh': 5264.909,
#       'segmentIndex': 1}]},
#    {'panelsCount': 37,
#     'yearlyEnergyDcKwh': 15198.906,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 23,
#       'yearlyEnergyDcKwh': 9549.586,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 14,
#       'yearlyEnergyDcKwh': 5649.3193,
#       'segmentIndex': 1}]},
#    {'panelsCount': 38,
#     'yearlyEnergyDcKwh': 15581.08,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 23,
#       'yearlyEnergyDcKwh': 9549.586,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 15,
#       'yearlyEnergyDcKwh': 6031.493,
#       'segmentIndex': 1}]},
#    {'panelsCount': 39,
#     'yearlyEnergyDcKwh': 15959.2705,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 24,
#       'yearlyEnergyDcKwh': 9927.776,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 15,
#       'yearlyEnergyDcKwh': 6031.493,
#       'segmentIndex': 1}]},
#    {'panelsCount': 40,
#     'yearlyEnergyDcKwh': 16337.265,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 24,
#       'yearlyEnergyDcKwh': 9927.776,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 16,
#       'yearlyEnergyDcKwh': 6409.488,
#       'segmentIndex': 1}]},
#    {'panelsCount': 41,
#     'yearlyEnergyDcKwh': 16714.068,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 24,
#       'yearlyEnergyDcKwh': 9927.776,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 17,
#       'yearlyEnergyDcKwh': 6786.291,
#       'segmentIndex': 1}]},
#    {'panelsCount': 42,
#     'yearlyEnergyDcKwh': 17085.252,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 25,
#       'yearlyEnergyDcKwh': 10298.96,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 17,
#       'yearlyEnergyDcKwh': 6786.291,
#       'segmentIndex': 1}]},
#    {'panelsCount': 43,
#     'yearlyEnergyDcKwh': 17449.688,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 17,
#       'yearlyEnergyDcKwh': 6786.291,
#       'segmentIndex': 1}]},
#    {'panelsCount': 44,
#     'yearlyEnergyDcKwh': 17795.79,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 18,
#       'yearlyEnergyDcKwh': 7132.393,
#       'segmentIndex': 1}]},
#    {'panelsCount': 45,
#     'yearlyEnergyDcKwh': 18141.025,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 19,
#       'yearlyEnergyDcKwh': 7477.63,
#       'segmentIndex': 1}]},
#    {'panelsCount': 46,
#     'yearlyEnergyDcKwh': 18485.887,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 20,
#       'yearlyEnergyDcKwh': 7822.4917,
#       'segmentIndex': 1}]},
#    {'panelsCount': 47,
#     'yearlyEnergyDcKwh': 18830.586,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 21,
#       'yearlyEnergyDcKwh': 8167.191,
#       'segmentIndex': 1}]},
#    {'panelsCount': 48,
#     'yearlyEnergyDcKwh': 19171.953,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 22,
#       'yearlyEnergyDcKwh': 8508.557,
#       'segmentIndex': 1}]},
#    {'panelsCount': 49,
#     'yearlyEnergyDcKwh': 19510.252,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 23,
#       'yearlyEnergyDcKwh': 8846.856,
#       'segmentIndex': 1}]},
#    {'panelsCount': 50,
#     'yearlyEnergyDcKwh': 19839.434,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 24,
#       'yearlyEnergyDcKwh': 9176.037,
#       'segmentIndex': 1}]},
#    {'panelsCount': 51,
#     'yearlyEnergyDcKwh': 20168.594,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 25,
#       'yearlyEnergyDcKwh': 9505.196,
#       'segmentIndex': 1}]},
#    {'panelsCount': 52,
#     'yearlyEnergyDcKwh': 20492.963,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 10663.395,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 9829.566,
#       'segmentIndex': 1}]},
#    {'panelsCount': 53,
#     'yearlyEnergyDcKwh': 20784.182,
#     'roofSegmentSummaries': [{'pitchDegrees': 45.861034,
#       'azimuthDegrees': 268.66965,
#       'panelsCount': 27,
#       'yearlyEnergyDcKwh': 10954.612,
#       'segmentIndex': 0},
#      {'pitchDegrees': 45.63353,
#       'azimuthDegrees': 88.49446,
#       'panelsCount': 26,
#       'yearlyEnergyDcKwh': 9829.566,
#       'segmentIndex': 1}]}],
#   'financialAnalyses': [{'monthlyBill': {'currencyCode': 'USD', 'units': '20'},
#     'panelConfigIndex': -1},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '25'},
#     'panelConfigIndex': -1},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '30'},
#     'panelConfigIndex': -1},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '35'},
#     'panelConfigIndex': 0,
#     'financialDetails': {'initialAcKwhPerYear': 1522.3263,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '5304'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '2239'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '137'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD', 'units': '9306'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 93.62188,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '408',
#       'nanos': 968475342},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-240'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4177'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3053',
#        'nanos': -96191406},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4177'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3053',
#        'nanos': -96191406}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '7465',
#       'nanos': 200195313},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '5226'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '2239',
#       'nanos': 560302734},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '169'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '4140'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-2404',
#        'nanos': -105712891},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '4140'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-2404',
#        'nanos': -105712891}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '413',
#       'nanos': 342010498},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-244'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4126'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3020',
#        'nanos': -620117188},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4126'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3020',
#        'nanos': -620117188}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '40'},
#     'panelConfigIndex': 1,
#     'financialDetails': {'initialAcKwhPerYear': 1889.6635,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '5842'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '2577'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '170'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '10809'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 87.14983,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '470',
#       'nanos': 303222656},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-260'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4438'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3262',
#        'nanos': -613525391},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4438'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3262',
#        'nanos': -613525391}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '8592'},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '6015'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '2577',
#       'nanos': 600097656},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '210'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '5139'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-2512',
#        'nanos': -728027344},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '5139'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-2512',
#        'nanos': -728027344}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '475',
#       'nanos': 732025146},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-266'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4376'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3222',
#        'nanos': -300048828},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4376'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3222',
#        'nanos': -300048828}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '45'},
#     'panelConfigIndex': 3,
#     'financialDetails': {'initialAcKwhPerYear': 2623.9917,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '5412'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '3253'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '237'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '12311'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 96.82949,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '592',
#       'nanos': 973388672},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-301'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4959'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3680',
#        'nanos': -48339844},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4959'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3680',
#        'nanos': -48339844}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '10845',
#       'nanos': 599609375},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '7592'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '3253',
#       'nanos': 680175781},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '292'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '7137'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-2728',
#        'nanos': -384521484},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '7137'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-2728',
#        'nanos': -384521484}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '600',
#       'nanos': 511962891},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-309'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-4873'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3624',
#        'nanos': -71777344},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-4873'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3624',
#        'nanos': -71777344}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '50'},
#     'panelConfigIndex': 4,
#     'financialDetails': {'initialAcKwhPerYear': 2989.521,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '5951'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '3591'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '270'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '13813'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 91.94725,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '654',
#       'nanos': 313293457},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-322'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-5224'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3891',
#        'nanos': -335937500},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-5224'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3891',
#        'nanos': -335937500}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '11972',
#       'nanos': 400390625},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '8381'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '3591',
#       'nanos': 720458984},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '333'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '8133'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-2838',
#        'nanos': -817138672},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '8133'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-2838',
#        'nanos': -817138672}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '662',
#       'nanos': 901977539},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-330'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-5125'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3827',
#        'nanos': -557617188},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-5125'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3827',
#        'nanos': -557617188}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '60'},
#     'panelConfigIndex': 7,
#     'financialDetails': {'initialAcKwhPerYear': 4066.6697,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '6125'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '4605'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '367'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '16818'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 93.791626,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '838',
#       'nanos': 389038086},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-386'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-6074'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-4564',
#        'nanos': -414550781},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-6074'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-4564',
#        'nanos': -414550781}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '15352',
#       'nanos': 799804688},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '10747'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '4605',
#       'nanos': 840332031},
#      'paybackYears': 19.5,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '453'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '11061'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3209',
#        'nanos': -739013672},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '11061'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3209',
#        'nanos': -739013672}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '850',
#       'nanos': 71960449},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-397'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-5940'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-4477',
#        'nanos': -645996094},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-5940'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-4477',
#        'nanos': -645996094}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '70'},
#     'panelConfigIndex': 10,
#     'financialDetails': {'initialAcKwhPerYear': 5133.914,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '6329'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '5619'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '464'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '19822'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 94.68969,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '1022',
#       'nanos': 492797852},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-451'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-6955'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-5258',
#        'nanos': -357421875},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-6955'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-5258',
#        'nanos': -357421875}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '18733',
#       'nanos': 199218750},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '13114'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '5619',
#       'nanos': 959960938},
#      'paybackYears': 18.75,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '571'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '13958'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-3601',
#        'nanos': -745605469},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '13958'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-3601',
#        'nanos': -745605469}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '1037',
#       'nanos': 241943359},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-466'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-6786'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-5148',
#        'nanos': -825195313},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-6786'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-5148',
#        'nanos': -825195313}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '80'},
#     'panelConfigIndex': 14,
#     'financialDetails': {'initialAcKwhPerYear': 6536.6816,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '5804'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '6972'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '590'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '22827'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 99.593475,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '1268',
#       'nanos': 22583008},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-547'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-8337'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-6323',
#        'nanos': -489257813},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-8337'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-6323',
#        'nanos': -489257813}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '23240',
#       'nanos': 400390625},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '16269'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '6972',
#       'nanos': 120605469},
#      'paybackYears': 18.5,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '721'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '17615'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-4264',
#        'nanos': -727050781},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '17615'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-4264',
#        'nanos': -727050781}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '1286',
#       'nanos': 802001953},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-566'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-8121'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-6184',
#        'nanos': -40039063},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-8121'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-6184',
#        'nanos': -40039063}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '90'},
#     'panelConfigIndex': 17,
#     'financialDetails': {'initialAcKwhPerYear': 7570.128,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '6404'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '7986'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '684'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '25831'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 97.54745,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '1452',
#       'nanos': 223876953},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-629'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-9617'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-7287',
#        'nanos': -910156250},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-9617'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-7287',
#        'nanos': -910156250}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '26620',
#       'nanos': 798828125},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '18635'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '7986',
#       'nanos': 240234375},
#      'paybackYears': 18.5,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '824'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '20112'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-4927',
#        'nanos': -922851563},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '20112'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-4927',
#        'nanos': -922851563}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '1473',
#       'nanos': 971923828},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-650'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-9367'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-7126',
#        'nanos': -400390625},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-9367'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-7126',
#        'nanos': -400390625}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '100'},
#     'defaultBill': True,
#     'panelConfigIndex': 21,
#     'financialDetails': {'initialAcKwhPerYear': 8917.467,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '6193'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '9338'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '806'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '28836'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 99.495674,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '1697',
#       'nanos': 913085938},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-737'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-11315'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-8568',
#        'nanos': -504882813},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-11315'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-8568',
#        'nanos': -504882813}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '31128'},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '21790'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '9338',
#       'nanos': 400390625},
#      'paybackYears': 18.75,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '961'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '23449'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-5807',
#        'nanos': -548828125},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '23449'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-5807',
#        'nanos': -548828125}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '1723',
#       'nanos': 531982422},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-763'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-11021'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-8378',
#        'nanos': -268554688},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-11021'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-8378',
#        'nanos': -268554688}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '125'},
#     'panelConfigIndex': 30,
#     'financialDetails': {'initialAcKwhPerYear': 11912.838,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '6655'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '12380'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '1076'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '36347'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 99.51465,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '2250',
#       'nanos': 817871094},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-990'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-15323'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-11576',
#        'nanos': -794921875},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-15323'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-11576',
#        'nanos': -794921875}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '41269',
#       'nanos': 199218750},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '28889'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '12380',
#       'nanos': 760742188},
#      'paybackYears': 18.75,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '1261'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '30770'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-7914',
#        'nanos': -417480469},
#       'financiallyViable': True,
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '30770'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-7914',
#        'nanos': -417480469}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '2285',
#       'nanos': 41748047},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1024'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-14931'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-11322',
#        'nanos': -636718750},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-14931'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-11322',
# ...
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '62678',
#       'nanos': 402343750},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '43875'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '18803',
#       'nanos': 521484375},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '1520'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '37480'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-18334',
#        'nanos': -660156250},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '37480'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-18334',
#        'nanos': -660156250}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '3470',
#       'nanos': 452148438},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1951'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-31929'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-23510',
#        'nanos': -966796875},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-31929'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-23510',
#        'nanos': -966796875}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '450'},
#     'panelConfigIndex': 49,
#     'financialDetails': {'initialAcKwhPerYear': 17633.455,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD', 'units': '98117'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '18803'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '1594'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '133996'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 31.209103,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '3419',
#       'nanos': 792724609},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1900'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-32517'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-23892',
#        'nanos': -236328125},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-32517'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-23892',
#        'nanos': -236328125}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '62678',
#       'nanos': 402343750},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '43875'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '18803',
#       'nanos': 521484375},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '1520'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '37473'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-18339',
#        'nanos': -740234375},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '37473'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-18339',
#        'nanos': -740234375}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '3470',
#       'nanos': 452148438},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1951'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-31936'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-23516',
#        'nanos': -44921875},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-31936'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-23516',
#        'nanos': -44921875}}}},
#    {'monthlyBill': {'currencyCode': 'USD', 'units': '500'},
#     'panelConfigIndex': 49,
#     'financialDetails': {'initialAcKwhPerYear': 17633.455,
#      'remainingLifetimeUtilityBill': {'currencyCode': 'USD',
#       'units': '113154'},
#      'federalIncentive': {'currencyCode': 'USD', 'units': '18803'},
#      'stateIncentive': {'currencyCode': 'USD'},
#      'utilityIncentive': {'currencyCode': 'USD'},
#      'lifetimeSrecTotal': {'currencyCode': 'USD', 'units': '1594'},
#      'costOfElectricityWithoutSolar': {'currencyCode': 'USD',
#       'units': '149018'},
#      'netMeteringAllowed': True,
#      'solarPercentage': 27.764877,
#      'percentageExportedToGrid': 0},
#     'leasingSavings': {'leasesAllowed': True,
#      'leasesSupported': True,
#      'annualLeasingCost': {'currencyCode': 'USD',
#       'units': '3419',
#       'nanos': 792724609},
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1901'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-32531'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-23901',
#        'nanos': -474609375},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-32531'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-23901',
#        'nanos': -474609375}}},
#     'cashPurchaseSavings': {'outOfPocketCost': {'currencyCode': 'USD',
#       'units': '62678',
#       'nanos': 402343750},
#      'upfrontCost': {'currencyCode': 'USD', 'units': '43875'},
#      'rebateValue': {'currencyCode': 'USD',
#       'units': '18803',
#       'nanos': 521484375},
#      'paybackYears': -1,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '1519'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '37459'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-18348',
#        'nanos': -976562500},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '37459'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-18348',
#        'nanos': -976562500}}},
#     'financedPurchaseSavings': {'annualLoanPayment': {'currencyCode': 'USD',
#       'units': '3470',
#       'nanos': 452148438},
#      'rebateValue': {'currencyCode': 'USD'},
#      'loanInterestRate': 0.05,
#      'savings': {'savingsYear1': {'currencyCode': 'USD', 'units': '-1951'},
#       'savingsYear20': {'currencyCode': 'USD', 'units': '-31950'},
#       'presentValueOfSavingsYear20': {'currencyCode': 'USD',
#        'units': '-23525',
#        'nanos': -283203125},
#       'savingsLifetime': {'currencyCode': 'USD', 'units': '-31950'},
#       'presentValueOfSavingsLifetime': {'currencyCode': 'USD',
#        'units': '-23525',
#        'nanos': -283203125}}}}],
#   'panelCapacityWatts': 400,
#   'panelHeightMeters': 1.879,
#   'panelWidthMeters': 1.045,
#   'panelLifetimeYears': 20,
#   'buildingStats': {'areaMeters2': 134.5044,
#    'sunshineQuantiles': [364.5252,
#     661.56635,
#     829.162,
#     914.52576,
#     949.2547,
#     971.8207,
#     993.70984,
#     1012.51465,
#     1035.8933,
#     1086.5116,
#     1346.6733],
#    'groundAreaMeters2': 91.21},
#   'solarPanels': [{'center': {'latitude': 41.0185071,
#      'longitude': -85.1676016},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 454.581,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184977, 'longitude': -85.1676016},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 454.03568,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185165, 'longitude': -85.16760169999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 448.76428,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184883, 'longitude': -85.1676016},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 436.95282,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185259, 'longitude': -85.16760169999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 432.9727,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185354, 'longitude': -85.16760169999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 433.10983,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185448, 'longitude': -85.16760169999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 432.42728,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185542, 'longitude': -85.1676018},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 430.8409,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185546, 'longitude': -85.1675843},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 426.39465,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185452, 'longitude': -85.1675842},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 421.9741,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0184977, 'longitude': -85.1676172},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 421.24402,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.018535799999995,
#      'longitude': -85.16758410000001},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 421.21756,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185263, 'longitude': -85.16758410000001},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 419.82498,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185169, 'longitude': -85.16758399999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 416.896,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0184883, 'longitude': -85.1676171},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 415.26767,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185071, 'longitude': -85.1676172},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 414.9185,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.01856360000001, 'longitude': -85.1676018},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 414.21722,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185165, 'longitude': -85.1676172},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 409.0097,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185075, 'longitude': -85.1675839},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 408.58246,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185259, 'longitude': -85.16761729999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 406.49493,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.018498099999995, 'longitude': -85.1675839},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 403.02255,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018535299999996,
#      'longitude': -85.16761729999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 401.9708,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185259, 'longitude': -85.16763279999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 396.19174,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184883, 'longitude': -85.1676327},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 394.96347,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185071, 'longitude': -85.16763279999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 394.95416,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184977, 'longitude': -85.1676327},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 394.8417,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185165, 'longitude': -85.16763279999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 394.82483,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184887, 'longitude': -85.1675838},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 394.11722,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185447, 'longitude': -85.16761729999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 393.87207,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0185546, 'longitude': -85.1675686},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 392.98743,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185452, 'longitude': -85.1675686},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 391.80276,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018535799999995, 'longitude': -85.1675685},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 390.6671,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185264, 'longitude': -85.16756840000001},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 390.25705,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018535299999996,
#      'longitude': -85.16763279999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 387.21042,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.018516999999996,
#      'longitude': -85.16756840000001},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 387.16534,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185542, 'longitude': -85.16761729999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 385.92126,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.018564, 'longitude': -85.1675843},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 384.41006,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185076, 'longitude': -85.1675683},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 382.17404,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185447, 'longitude': -85.1676329},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 378.19003,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184888, 'longitude': -85.16756819999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 377.99478,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018498199999996,
#      'longitude': -85.16756819999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 376.80328,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018554099999996, 'longitude': -85.1676329},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 371.18384,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.01856360000001, 'longitude': -85.1676174},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 364.43445,
#     'segmentIndex': 0},
#    {'center': {'latitude': 41.0184888, 'longitude': -85.1675525},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 346.10205,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018554699999996, 'longitude': -85.167553},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 345.23706,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185453, 'longitude': -85.16755289999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 344.8619,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018535899999996,
#      'longitude': -85.16755289999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 344.69916,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185265, 'longitude': -85.1675528},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 341.36612,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185641, 'longitude': -85.16756869999999},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 338.29977,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.018498199999996, 'longitude': -85.1675526},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 329.18097,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185171, 'longitude': -85.1675527},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 329.15964,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185076, 'longitude': -85.1675527},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 324.3699,
#     'segmentIndex': 1},
#    {'center': {'latitude': 41.0185635, 'longitude': -85.1676329},
#     'orientation': 'PORTRAIT',
#     'yearlyEnergyDcKwh': 291.21774,
#     'segmentIndex': 0}]},
#  'boundingBox': {'sw': {'latitude': 41.0184797, 'longitude': -85.1676509},
#   'ne': {'latitude': 41.018575999999996, 'longitude': -85.16753779999999}},
#  'imageryQuality': 'HIGH',
#  'imageryProcessedDate': {'year': 2024, 'month': 4, 'day': 18}}
